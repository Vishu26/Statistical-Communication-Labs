# %% [markdown]
# <a href="https://colab.research.google.com/github/Vishu26/Statistical-Communication-Labs/blob/master/LAB_4_Joint_Density_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# %% [markdown]
# ## Histogram

# %%
def hist(x,no_bins):
    no_samples = np.size(x)
    x_max = max(x)
    x_min = min(x)
    bins = np.linspace(x_min,x_max,no_bins)
    bin_width = abs(bins[1] - bins[0])
    freq = np.zeros(shape=(no_bins))
    for i in range(no_samples):
        for j in range(no_bins):
            if(x[i] <= bins[j]+0.5*bin_width and x[i] > bins[j]-bin_width):
                freq[j] += 1
                break
    freq =freq/(no_samples)
    return bins,freq

# %%
M = 10000 # Number of samples
no_bins = 30 #Number of bins for histogram

# %% [markdown]
# ## <font color='red'>1. Show graphically for independently generated random variable $X$ and $Y$, $$f_{xy}(x,y)=f_x(x)f_y(y).$$ </font>
# Note: Generate $X$ and $Y$ from Gaussian distribution with 0 mean and variance 1.

# %% [markdown]
# ### Generate $X$.

# %%
X = np.random.normal(0, 1, M)
[x,fx]=hist(X,no_bins)
plt.figure()
plt.plot(x,fx)

# %% [markdown]
# ### Generate $Y$.

# %%
Y = np.random.normal(0, 1, M)
[y,fy]=hist(Y,no_bins)
plt.figure()
plt.plot(y,fy)

# %% [markdown]
# ### Now find $f_{xy}(x,y)$ using $f_x(x)$ and $f_y(y)$.
# HINT: $[f_{xy}(x,y)]_{no\_bins*no\_bins} = [f_{x}(x)]_{no\_bins \times 1} \times [f_{y}(y)]_{1\times no\_bins}$

# %%
fig = plt.figure()
#write code here
ax = fig.gca(projection='3d')
fxy = fx.reshape(no_bins, 1).dot(fy.reshape(1, no_bins))
print(fxy.shape)
x1,y1 = np.meshgrid(x,y)
surf = ax.plot_surface(x1,y1, fxy, cmap=cm.coolwarm)
# Out:
# (30, 30)

# %% [markdown]
# ### Write code for joint histogram of two variable

# %%
def hist2(x,y,no_bins):
    freq = np.zeros((no_bins, no_bins))
    no_samples = np.size(x)
    x_max = max(x)
    x_min = min(x)
    y_max = max(y)
    y_min = min(y)
    binsx = np.linspace(x_min,x_max,no_bins)
    binsy = np.linspace(y_min,y_max,no_bins)
    bin_width_x = abs(binsx[1] - binsx[0])
    bin_width_y = abs(binsy[1] - binsy[0])
    for i in range(no_samples):
      for l in range(no_bins):
        for k in range(no_bins):
          if (x[i] <= binsx[l]+0.5*bin_width_x and x[i] > binsx[l]-bin_width_x and y[i] <= binsy[k]+0.5*bin_width_y and y[i] > binsy[k]-bin_width_y):
              freq[l][k]+=1
    freq =freq/(no_samples)
    return binsx,binsy,freq

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
[x,y,fxy] = hist2(X,Y,no_bins)
x1,y1 = np.meshgrid(x,y)
surf = ax.plot_surface(x1,y1,fxy, cmap=cm.coolwarm)

# %% [markdown]
# ## <font color='red'>2. Generate random variable $X$ and $Z=2X+3$. Plot $f_{xz}(x,z)$,and  $f_x(x)f_z(z)$ . X and Z are independent?</font>

# %% [markdown]
# ### Generate Z

# %%
Z=2*X + 3
[z,fz]=hist(Z,no_bins)
plt.figure()
plt.plot(z,fz)

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
#write code here
fxz = fx.reshape(no_bins, 1).dot(fz.reshape(1, no_bins))
x1,z1 = np.meshgrid(x,z)
surf = ax.plot_surface(x1,z1, fxz, cmap=cm.coolwarm)

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
[x,z,fxz] = hist2(X,Z,no_bins)
x1,z1 = np.meshgrid(x,z)
surf = ax.plot_surface(x1,z1,fxz, cmap=cm.coolwarm)

# %% [markdown]
# ## <font color='red'>3. If $X$ and $Y$ are uniform random variable with $-1<x,y<1$ and $Z=X+Y$, plot $f_X(x)$,$f_Y(y)$ and $f_Z(z)$.</font>

# %%
X = np.random.uniform(-1, 1, M)
[x,fx]=hist(X,no_bins)
plt.figure()
plt.plot(x,fx)

# %%
Y = np.random.uniform(-1, 1, M)
[y,fy]=hist(Y,no_bins)
plt.figure()
plt.plot(y,fy)

# %%
Z=X+Y
[z,fz]=hist(Z,no_bins)
plt.figure()
plt.plot(z,fz)
